# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from clean_data import load_data, dt_ck

# %%
bj_speed = load_data('bj', 'speed', 'None')
sh_speed = load_data('sh', 'speed', 'None')
bj_adj = load_data('bj', 'adj', 'None')
sh_adj = load_data('sh', 'adj', 'None')

sh_pro_id = dt_ck(sh_speed)
bj_pro_id = dt_ck(bj_speed)

# %%
len(sh_pro_id), len(bj_pro_id)
# Out:
# (28, 4)

# %%
sh_pro_id
# Out:
# [0,
#  1,
#  212,
#  213,
#  214,
#  215,
#  258,
#  329,
#  330,
#  331,
#  650,
#  651,
#  823,
#  843,
#  844,
#  874,
#  875,
#  885,
#  888,
#  980,
#  981,
#  1067,
#  1245,
#  1288,
#  1316,
#  1332,
#  1333,
#  1334]

# %%
bj_pro_id
# Out:
# [156, 157, 523, 524]

# %%
# plt.plot(np.arange(0,bj_speed.shape[0]), bj_speed[:,156])

# %%
# plt.plot(np.arange(0,bj_speed.shape[0]), bj_speed[:,157])

# %%
# plt.plot(np.arange(0,bj_speed.shape[0]), bj_speed[:,523])

# %%
# plt.plot(np.arange(0,sh_speed.shape[0]), sh_speed[:,212])

# %%
# plt.plot(np.arange(0,sh_speed.shape[0]), sh_speed[:,888])

# %%
clc_sh_speed = np.delete(sh_speed, sh_pro_id, axis=1)

# %%
clc_sh_speed.shape
# Out:
# (8928, 1307)

# %%
clc_bj_speed = np.delete(bj_speed, bj_pro_id, axis=1)

# %%
clc_bj_speed.shape
# Out:
# (8928, 1155)

# %%
bj_dataframe = pd.DataFrame(clc_bj_speed)
sh_dataframe = pd.DataFrame(clc_sh_speed)
bj_dataframe.to_csv("clc_bj_speed.csv",index=False,sep=',',header=None)
sh_dataframe.to_csv("clc_sh_speed.csv",index=False,sep=',',header=None)

# %%
clc_bj_adj = np.delete(bj_adj, bj_pro_id, axis=1)
clc_bj_adj = np.delete(clc_bj_adj, bj_pro_id, axis=0)

# %%
clc_sh_adj = np.delete(sh_adj, sh_pro_id, axis=1)
clc_sh_adj = np.delete(clc_sh_adj, sh_pro_id, axis=0)

# %%
bjadj_dataframe = pd.DataFrame(clc_bj_adj)
shadj_dataframe = pd.DataFrame(clc_sh_adj)
bjadj_dataframe.to_csv("clc_bj_adj.csv",index=False,sep=',',header=None)
shadj_dataframe.to_csv("clc_sh_adj.csv",index=False,sep=',',header=None)

# %%
clc_bj_adj.shape, clc_sh_adj.shape
# Out:
# ((1155, 1155), (1307, 1307))

# %%
clc_sh_speed.mean()
# Out:
# 35.10959939997751

# %%
clc_bj_speed.mean()
# Out:
# 36.43869930099769
